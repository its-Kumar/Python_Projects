# %%
import requests
import base64
import datetime

# %%
client_id = '********************'
client_secret = '********************'

# %%
class SpotifyAPI(object):
    """
    Spotify Client
    
    Parameters
    ---
    client_id : str
    client_secret : str
    """
    token_url = "https://accounts.spotify.com/api/token"
    access_token = None
    access_token_expires = datetime.datetime.now()
    client_id = None
    client_secret = None

    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns :  a base 64 encoded string.
        """
        if self.client_id is None or self.client_secret is None:
            raise Exception("You must set client_id and client_secret")
        client_cred = f"{self.client_id}:{self.client_secret}"
        client_cred_b64 = base64.b64encode(client_cred.encode())
        return client_cred_b64.decode()

    def get_token_headers(self):
        client_cred_b64 = self.get_client_credentials()
        return {
            'Authorization': f'Basic {client_cred_b64}'}

    def get_token_data(self):
        return {
            'grant_type': 'client_credentials'
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_header = self.get_token_headers()
        r = requests.post(token_url,
                          data=token_data,
                          headers=token_header)
        if r.status_code not in range(200, 299):
            raise Exception('Could not authenticate client')
        data = r.json()
        now = datetime.datetime.now()
        self.access_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            return self.perform_auth()
        elif token is None:
            self.perform_auth()
            return self.get_access_token()
        return token

    def get_resource_header(self):
        access_token = self.access_token
        headers = {
            'Authorization' : f"Bearer {access_token}"
            }
        return headers


    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
             return {}
        return r.json()

    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')


    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
   
    def base_search(self, query_params):
        headers = self.get_resource_header()
        endpoint = 'https://api.spotify.com/v1/search'
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url, headers=headers)
        print(r.status_code)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()


    def search(self, query=None, operator=None, operator_query=None, search_type='artist'):
        from urllib.parse import urlencode
        if query is None:
            raise Exception('A query is required to search')
        if isinstance(query, dict):
            query = " ".join([f"{k}:{v}" for (k, v) in query.items()])
        if operator is not None and operator_query is not None:
            if operator.lower() == 'or' or  operator.lower() == 'not':
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type": search_type.lower()})
        print(query_params)
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.perform_auth()
# Out:
# True

# %%
spotify.search({"track": "A lennister always pays his debts", "artist":"Ramin"}, search_type='track')
# Out:
# q=track%3AA+lennister+always+pays+his+debts+artist%3ARamin&type=track
# 200
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AA+lennister+always+pays+his+debts+artist%3ARamin&type=track&offset=0&limit=20',
#   'items': [],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}

# %%
spotify.search('kumar sanu', 'artist')
# Out:
# q=kumar+sanu&type=artist
# 200
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=kumar+sanu&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4K6blSRoklNdpw4mzLxwfn'},
#     'followers': {'href': None, 'total': 2547918},
#     'genres': ['classic bollywood',
#      'desi pop',
#      'filmi',
#      'modern bollywood',
#      'sufi'],
#     'href': 'https://api.spotify.com/v1/artists/4K6blSRoklNdpw4mzLxwfn',
#     'id': '4K6blSRoklNdpw4mzLxwfn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/b802604a568d80882fb4e0ed5862f52aeed4c2fa',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/07396382e84791f83505efb6bf9934823443fd18',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/05fbe4fe546ca10b31f18b621138f7a90d52c01f',
#       'width': 160}],
#     'name': 'Kumar Sanu',
#     'popularity': 67,
#     'type': 'artist',
#     'uri': 'spotify:artist:4K6blSRoklNdpw4mzLxwfn'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4CtTpmxKjgeGItnx9oOv2x'},
#     'followers': {'href': None, 'total': 469},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4CtTpmxKjgeGItnx9oOv2x',
#     'id': '4CtTpmxKjgeGItnx9oOv2x',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273
'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/53dD5Cu819Eyd58mNwS7Mm'},
#     'followers': {'href': None, 'total': 9},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/53dD5Cu819Eyd58mNwS7Mm',
#     'id': '53dD5Cu819Eyd58mNwS7Mm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f8d3b90d716696dc08c9f6fa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f8d3b90d716696dc08c9f6fa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f8d3b90d716696dc08c9f6fa',
#       'width': 64}],
#     'name': 'Jatin Lalit, Kumar Sanu, Kavita Krishnamurty',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:53dD5Cu819Eyd58mNwS7Mm'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Kqma04AZtjyQQLiaeV7Ro'},
#     'followers': {'href': None, 'total': 22},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7Kqma04AZtjyQQLiaeV7Ro',
#     'id': '7Kqma04AZtjyQQLiaeV7Ro',
#     'images': [],
#     'name': 'Shaan / Sunidhi Chauhan / Kumar Sanu / Soumya Raoh / Alka Yagnik / Vishal',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:7Kqma04AZtjyQQLiaeV7Ro'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5I6qe8URgGxWi460W22GQg'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5I6qe8URgGxWi460W22GQg',
#     'id': '5I6qe8URgGxWi460W22GQg',
#     'images': [],
#     'name': 'Asha Bhonsle, Kumar Sanu',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:5I6qe8URgGxWi460W22GQg'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ZVyM7kby2ZiZMiLUlmNhp'},
#     'followers': {'href': None, 'total': 115},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4ZVyM7kby2ZiZMiLUlmNhp',
#     'id': '4ZVyM7kby2ZiZMiLUlmNhp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734ff62081a7d42c862065a92a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024ff62081a7d42c862065a92a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514ff62081a7d42c862065a92a',
#       'width': 64}],
#     'name': 'R.D.Burman, Kumar Sanu, Asha Bhonsle, Amit Kumar, Md.Aziz, Lata Mangeskar',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:4ZVyM7kby2ZiZMiLUlmNhp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2UXKKqqzsmYEB19N2oaA95'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2UXKKqqzsmYEB19N2oaA95',
#     'id': '2UXKKqqzsmYEB19N2oaA95',
#     'images': [],
#     'name': 'Kumar Sanu, Sadhna Sargum',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2UXKKqqzsmYEB19N2oaA95'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/22gal0TUs6J3Xd9kEKWgbC'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/22gal0TUs6J3Xd9kEKWgbC',
#     'id': '22gal0TUs6J3Xd9kEKWgbC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273702dbe92edc923982e76dbb3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02702dbe92edc923982e76dbb3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851702dbe92edc923982e76dbb3',
#       'width': 64}],
#     'name': 'Amit Kumar, Kumar Sanu, Jayanti Sen',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:22gal0TUs6J3Xd9kEKWgbC'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tHsXmL6GzVzeDl1d33cnV'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/3tHsXmL6GzVzeDl1d33cnV',
#     'id': '3tHsXmL6GzVzeDl1d33cnV',
#     'images': [],
#     'name': 'Kumar Sanu, Sriradha Bandhyapadhya',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:3tHsXmL6GzVzeDl1d33cnV'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6zC3Phtq3KLVf71GoOnybe'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6zC3Phtq3KLVf71GoOnybe',
#     'id': '6zC3Phtq3KLVf71GoOnybe',
#     'images': [],
#     'name': 'Kumar Sanu, Anupama Deshpandey',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6zC3Phtq3KLVf71GoOnybe'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6HSu5UVHVtAPVbuKpOONFJ'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6HSu5UVHVtAPVbuKpOONFJ',
#     'id': '6HSu5UVHVtAPVbuKpOONFJ',
#     'images': [],
#     'name': 'Amit Kumar, Kumar Sanu, Anupama',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6HSu5UVHVtAPVbuKpOONFJ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ck2ZS3amQYNuIU8E73llf'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6ck2ZS3amQYNuIU8E73llf',
#     'id': '6ck2ZS3amQYNuIU8E73llf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733e60c6d7d5e81602554f9ccd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023e60c6d7d5e81602554f9ccd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513e60c6d7d5e81602554f9ccd',
#       'width': 64}],
#     'name': 'Abhay Kumar Sanu',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6ck2ZS3amQYNuIU8E73llf'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=kumar+sanu&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 49}}

# %%
import pprint
s = spotify.search(query='Time', operator='not', operator_query='Billie Elish', search_type='track')
pprint.pprint(s)
# Out:
# eRptr5'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/23aDnReg0IXiOovrebZd2D'},
#                                     'href': 'https://api.spotify.com/v1/artists/23aDnReg0IXiOovrebZd2D',
#                                     'id': '23aDnReg0IXiOovrebZd2D',
#                                     'name': 'Elisha Cook Hamilton',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:23aDnReg0IXiOovrebZd2D'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AL',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BA',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'BY',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HR',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'KZ',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MD',
#                                              'ME',
#                                              'MK',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'RS',
#                                              'RU',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SI',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'UA',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'XK',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 154527,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'QZNMT2031623'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/2rGsm1bU1atL8tkrG0Le9U'},
#                        'href': 'https://api.spotify.com/v1/tracks/2rGsm1bU1atL8tkrG0Le9U',
#                        'id': '2rGsm1bU1atL8tkrG0Le9U',
#                        'is_local': False,
#                        'name': 'Problem With You',
#                        'popularity': 0,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/fe088276bb3707f8cf49f99983220606b6e0a90b?cid=24876c6068de40989023a5e98c0c91e9',
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:2rGsm1bU1atL8tkrG0Le9U'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ooHx4zvETgLILfKLBh9g9'},
#                                               'href': 'https://api.spotify.com/v1/artists/4ooHx4zvETgLILfKLBh9g9',
#                                               'id': '4ooHx4zvETgLILfKLBh9g9',
#                                               'name': 'Elisha Israel & AZ-ONE',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4ooHx4zvETgLILfKLBh9g9'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AL',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'BA',
#                                                        'BE',
#                                                        'BG',
#                                                        'BH',
#                                                        'BO',
#                                                        'BR',
#                                                        'BY',
#                                                        'CA',
#                                                        'CH',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DK',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FR',
#                                                        'GB',
#                                                        'GR',
#                                                        'GT',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JO',
#                                                        'JP',
#                                                        'KW',
#                                                        'KZ',
#                                                        'LB',
#                                                        'LI',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MD',
#                                                        'ME',
#                                                        'MK',
#                                                        'MT',
#                                                        'MX',
#                                                        'MY',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'RU',
#                                                        'SA',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SV',
#                                                        'TH',
#                                                        'TN',
#                                                        'TR',
#                                                        'TW',
#                                                        'UA',
#                                                        'US',
#                                                        'UY',
#                                                        'VN',
#                                                        'XK',
#                                                        'ZA'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/5AvvIwl1XoihgBfLeYiv3T'},
#                                  'href': 'https://api.spotify.com/v1/albums/5AvvIwl1XoihgBfLeYiv3T',
#                                  'id': '5AvvIwl1XoihgBfLeYiv3T',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273d916023b03accc3603a7b240',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02d916023b03accc3603a7b240',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851d916023b03accc3603a7b240',
#                                              'width': 64}],
#                                  'name': 'Crucial Times',
#                                  'release_date': '2005-06-15',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 9,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:5AvvIwl1XoihgBfLeYiv3T'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ooHx4zvETgLILfKLBh9g9'},
#                                     'href': 'https://api.spotify.com/v1/artists/4ooHx4zvETgLILfKLBh9g9',
#                                     'id': '4ooHx4zvETgLILfKLBh9g9',
#                                     'name': 'Elisha Israel & AZ-ONE',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4ooHx4zvETgLILfKLBh9g9'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AL',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'BA',
#                                              'BE',
#                                              'BG',
#                                              'BH',
#                                              'BO',
#                                              'BR',
#                                              'BY',
#                                              'CA',
#                                              'CH',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DK',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FR',
#                                              'GB',
#                                              'GR',
#                                              'GT',
#                                              'HK',
#                                              'HN',
#                                              'HR',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JO',
#                                              'JP',
#                                              'KW',
#                                              'KZ',
#                                              'LB',
#                                              'LI',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MD',
#                                              'ME',
#                                              'MK',
#                                              'MT',
#                                              'MX',
#                                              'MY',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'RS',
#                                              'RU',
#                                              'SA',
#                                              'SE',
#                                              'SG',
#                                              'SI',
#                                              'SK',
#                                              'SV',
#                                              'TH',
#                                              'TN',
#                                              'TR',
#                                              'TW',
#                                              'UA',
#                                              'US',
#                                              'UY',
#                                              'VN',
#                                              'XK',
#                                              'ZA'],
#                        'disc_number': 1,
#                        'duration_ms': 256320,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'ushm90538789'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6faR4a09SEB2XXRYpL1Utx'},
#                        'href': 'https://api.spotify.com/v1/tracks/6faR4a09SEB2XXRYpL1Utx',
#                        'id': '6faR4a09SEB2XXRYpL1Utx',
#                        'is_local': False,
#                        'name': 'Arise',
#                        'popularity': 0,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/7ae3ba2efba74672fcf7b679f1b059d74eb9534f?cid=24876c6068de40989023a5e98c0c91e9',
#                        'track_number': 6,
#                        'type': 'track',
#                        'uri': 'spotify:track:6faR4a09SEB2XXRYpL1Utx'}],
#             'limit': 20,
#             'next': 'https://api.spotify.com/v1/search?query=Time+NOT+Billie+Elish&type=track&offset=20&limit=20',
#             'offset': 0,
#             'previous': None,
#             'total': 26}}
