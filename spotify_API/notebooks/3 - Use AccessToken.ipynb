# %%
import requests
import base64
import datetime

# %%
client_id = '********************'
client_secret = '********************'

# %%
class SpotifyAPI(object):
    """
    Spotify Client
    
    Parameters
    ---
    client_id : str
    client_secret : str
    """
    token_url = "https://accounts.spotify.com/api/token"
    access_token = None
    access_token_expires = datetime.datetime.now()
    client_id = None
    client_secret = None

    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns :  a base 64 encoded string.
        """
        if self.client_id is None or self.client_secret is None:
            raise Exception("You must set client_id and client_secret")
        client_cred = f"{self.client_id}:{self.client_secret}"
        client_cred_b64 = base64.b64encode(client_cred.encode())
        return client_cred_b64.decode()

    def get_token_headers(self):
        client_cred_b64 = self.get_client_credentials()
        return {
            'Authorization': f'Basic {client_cred_b64}'}

    def get_token_data(self):
        return {
            'grant_type': 'client_credentials'
        }

    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_header = self.get_token_headers()
        r = requests.post(token_url,
                          data=token_data,
                          headers=token_header)
        if r.status_code not in range(200, 299):
            return False
        data = r.json()
        now = datetime.datetime.now()
        self.access_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

# %%
client = SpotifyAPI(client_id, client_secret)

# %%
client.perform_auth()
# Out:
# True

# %%
access_token = client.access_token

# %%
from urllib.parse import urlencode
header = {
    'Authorization' : f"Bearer {access_token}"
}
endpoint = 'https://api.spotify.com/v1/search'
# data = {"q": "Time", "type": "track"}
data = urlencode({"q": "Time", "type": "track"})
lookup_url = f"{endpoint}?{data}"
print(lookup_url)
r = requests.get(lookup_url, headers=header)
r.status_code
# Out:
# https://api.spotify.com/v1/search?q=Time&type=track
# 200

# %%
r.json()
# Out:
# b67616d000048519dcf31d6b5eb82fa24de783a',
#        'width': 64}],
#      'name': 'One-X',
#      'release_date': '2006-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4ZDwEvXIKxWdwhAQK8ndBU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xiIXseIJcq3nG7C8fHeBj'},
#       'href': 'https://api.spotify.com/v1/artists/2xiIXseIJcq3nG7C8fHeBj',
#       'id': '2xiIXseIJcq3nG7C8fHeBj',
#       'name': 'Three Days Grace',
#       'type': 'artist',
#       'uri': 'spotify:artist:2xiIXseIJcq3nG7C8fHeBj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 186373,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10600165'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7piw04hPQZ1OHZ9Fq9JOXR'},
#     'href': 'https://api.spotify.com/v1/tracks/7piw04hPQZ1OHZ9Fq9JOXR',
#     'id': '7piw04hPQZ1OHZ9Fq9JOXR',
#     'is_local': False,
#     'name': 'Time of Dying',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d2da079180cf8de8d90982c820de59c15fe207ee?cid=24876c6068de40989023a5e98c0c91e9',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:7piw04hPQZ1OHZ9Fq9JOXR'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SlWk9stVDNIL6l4BK2MlI'},
#        'href': 'https://api.spotify.com/v1/artists/4SlWk9stVDNIL6l4BK2MlI',
#        'id': '4SlWk9stVDNIL6l4BK2MlI',
#        'name': 'Danielle Fleur',
#        'type': 'artist',
#        'uri': 'spotify:artist:4SlWk9stVDNIL6l4BK2MlI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7c9zTWwG3gmkYRqWomwQ6Q'},
#      'href': 'https://api.spotify.com/v1/albums/7c9zTWwG3gmkYRqWomwQ6Q',
#      'id': '7c9zTWwG3gmkYRqWomwQ6Q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731690615203568b7a755edab1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021690615203568b7a755edab1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511690615203568b7a755edab1',
#        'width': 64}],
#      'name': 'Time is the Longest Distance',
#      'release_date': '2020-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7c9zTWwG3gmkYRqWomwQ6Q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4SlWk9stVDNIL6l4BK2MlI'},
#       'href': 'https://api.spotify.com/v1/artists/4SlWk9stVDNIL6l4BK2MlI',
#       'id': '4SlWk9stVDNIL6l4BK2MlI',
#       'name': 'Danielle Fleur',
#       'type': 'artist',
#       'uri': 'spotify:artist:4SlWk9stVDNIL6l4BK2MlI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 124452,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5IB2001149'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1vViUoB7DpXUX10isPj7YL'},
#     'href': 'https://api.spotify.com/v1/tracks/1vViUoB7DpXUX10isPj7YL',
#     'id': '1vViUoB7DpXUX10isPj7YL',
#     'is_local': False,
#     'name': 'Time is the Longest Distance',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eb4ca522f1ca9f64dac200b1d92c6196309d6dbd?cid=24876c6068de40989023a5e98c0c91e9',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1vViUoB7DpXUX10isPj7YL'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6fOMl44jA4Sp5b9PpYCkzz'},
#        'href': 'https://api.spotify.com/v1/artists/6fOMl44jA4Sp5b9PpYCkzz',
#        'id': '6fOMl44jA4Sp5b9PpYCkzz',
#        'name': 'NF',
#        'type': 'artist',
#        'uri': 'spotify:artist:6fOMl44jA4Sp5b9PpYCkzz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1QcPl6AFNTiczxCuSpOoEM'},
#      'href': 'https://api.spotify.com/v1/albums/1QcPl6AFNTiczxCuSpOoEM',
#      'id': '1QcPl6AFNTiczxCuSpOoEM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736f07af4a86517f029f4737c8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026f07af4a86517f029f4737c8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516f07af4a86517f029f4737c8',
#        'width': 64}],
#      'name': 'Time',
#      'release_date': '2019-07-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1QcPl6AFNTiczxCuSpOoEM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6fOMl44jA4Sp5b9PpYCkzz'},
#       'href': 'https://api.spotify.com/v1/artists/6fOMl44jA4Sp5b9PpYCkzz',
#       'id': '6fOMl44jA4Sp5b9PpYCkzz',
#       'name': 'NF',
#       'type': 'artist',
#       'uri': 'spotify:artist:6fOMl44jA4Sp5b9PpYCkzz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 230610,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71912306'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/68Vm2W4oURsPV3121vUZgB'},
#     'href': 'https://api.spotify.com/v1/tracks/68Vm2W4oURsPV3121vUZgB',
#     'id': '68Vm2W4oURsPV3121vUZgB',
#     'is_local': False,
#     'name': 'Time - Edit',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:68Vm2W4oURsPV3121vUZgB'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4QviryaneolcRmDB57SLco'},
#      'href': 'https://api.spotify.com/v1/albums/4QviryaneolcRmDB57SLco',
#      'id': '4QviryaneolcRmDB57SLco',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737bcc78f88610d99eaa8c9b50',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027bcc78f88610d99eaa8c9b50',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517bcc78f88610d99eaa8c9b50',
#        'width': 64}],
#      'name': 'The Rocky Horror Picture Show - Original Soundtrack',
#      'release_date': '1975-01-10',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:4QviryaneolcRmDB57SLco'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/213WFYdlgojElnXhDyhwke'},
#       'href': 'https://api.spotify.com/v1/artists/213WFYdlgojElnXhDyhwke',
#       'id': '213WFYdlgojElnXhDyhwke',
#       'name': 'Little Nell',
#       'type': 'artist',
#       'uri': 'spotify:artist:213WFYdlgojElnXhDyhwke'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Akz0poR4eUgNM0ciCWqIs'},
#       'href': 'https://api.spotify.com/v1/artists/7Akz0poR4eUgNM0ciCWqIs',
#       'id': '7Akz0poR4eUgNM0ciCWqIs',
#       'name': 'Patricia Quinn',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Akz0poR4eUgNM0ciCWqIs'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0aIOdrjH5s3hJqxmKoAEUg'},
#       'href': 'https://api.spotify.com/v1/artists/0aIOdrjH5s3hJqxmKoAEUg',
#       'id': '0aIOdrjH5s3hJqxmKoAEUg',
#       'name': "Richard O'Brien",
#       'type': 'artist',
#       'uri': 'spotify:artist:0aIOdrjH5s3hJqxmKoAEUg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 199366,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560853992'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4WFeJTXNHIS2wURtwlAkhu'},
#     'href': 'https://api.spotify.com/v1/tracks/4WFeJTXNHIS2wURtwlAkhu',
#     'id': '4WFeJTXNHIS2wURtwlAkhu',
#     'is_local': False,
#     'name': 'Time Warp',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d7083545f4fe053c62e963a2f67695332536aa8?cid=24876c6068de40989023a5e98c0c91e9',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4WFeJTXNHIS2wURtwlAkhu'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7sgIedcWiWvEZGvIHgABbo'},
#        'href': 'https://api.spotify.com/v1/artists/7sgIedcWiWvEZGvIHgABbo',
#        'id': '7sgIedcWiWvEZGvIHgABbo',
#        'name': 'Olim',
#        'type': 'artist',
#        'uri': 'spotify:artist:7sgIedcWiWvEZGvIHgABbo'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Nj3e0AhYcqRqUd0AV2MmB'},
#      'href': 'https://api.spotify.com/v1/albums/2Nj3e0AhYcqRqUd0AV2MmB',
#      'id': '2Nj3e0AhYcqRqUd0AV2MmB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ffeccbe558d4f5f4483e2b69',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ffeccbe558d4f5f4483e2b69',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ffeccbe558d4f5f4483e2b69',
#        'width': 64}],
#      'name': 'MFWT Vol.1',
#      'release_date': '2020-06-22',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:2Nj3e0AhYcqRqUd0AV2MmB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7sgIedcWiWvEZGvIHgABbo'},
#       'href': 'https://api.spotify.com/v1/artists/7sgIedcWiWvEZGvIHgABbo',
#       'id': '7sgIedcWiWvEZGvIHgABbo',
#       'name': 'Olim',
#       'type': 'artist',
#       'uri': 'spotify:artist:7sgIedcWiWvEZGvIHgABbo'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 124655,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE4RG2062302'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1g0Zj4GZ229O647Tt3RPJ2'},
#     'href': 'https://api.spotify.com/v1/tracks/1g0Zj4GZ229O647Tt3RPJ2',
#     'id': '1g0Zj4GZ229O647Tt3RPJ2',
#     'is_local': False,
#     'name': 'Time',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/75884a9e60f5f993b56941c0e00b5d79add05957?cid=24876c6068de40989023a5e98c0c91e9',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1g0Zj4GZ229O647Tt3RPJ2'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Time&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100017}}

# %%
data = urlencode({"q":"A lenister always pays his debts", "type": "track"})
lookup_url = f"{endpoint}?{data}"
r = requests.get(lookup_url, headers=header)
r.json()
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=A+lenister+always+pays+his+debts&type=track&offset=0&limit=20',
#   'items': [],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0}}
